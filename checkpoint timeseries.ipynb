# %%
import pandas as pd
series=pd.read_csv("AirPassengers.csv",header=0, parse_dates=[0], index_col=0)
series
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121
# ...                 ...
# 1960-08-01          606
# 1960-09-01          508
# 1960-10-01          461
# 1960-11-01          390
# 1960-12-01          432
#
# [144 rows x 1 columns]

# %%
import datetime
x = datetime.datetime.now()
print(x)

# %%
from datetime import datetime
datetime(year=2015, month=7, day=4)
# Out:
# datetime.datetime(2015, 7, 4, 0, 0)

# %%
pd.Series(range(3), index=pd.date_range("2000", freq="D", periods=3))
# Out:
# 2000-01-01    0
# 2000-01-02    1
# 2000-01-03    2
# Freq: D, dtype: int64

# %%
pd.Series(pd.date_range("2000", freq="D", periods=3))
# Out:
# 0   2000-01-01
# 1   2000-01-02
# 2   2000-01-03
# dtype: datetime64[ns]

# %%
from matplotlib import pyplot
pyplot.plot(series) # creates a time series plot with the number of daily births on the y-axis and time in days along the x-axis.
pyplot.show()

# %%
import matplotlib.pyplot as plt
def plot_timeseries(df, x, y, title="", xlabel='Month', ylabel='Passengers', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()

plot_timeseries(series, x=series.index, y=series.iloc[:,1], title='Monthly Passengers in 1949-1960')
Chat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 9>()
#       6     plt.show()
#       8 plot_timeseries(series, x=series.index, y=series.iloc[:,1], title='Monthly Passengers in 1949-1960')
# ----> 9 Chat
#
# NameError: name 'Chat' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [19], in <cell line: 6>()
#       3 import matplotlib.pyplot as plt
#       5 # Month and year extraction
# ----> 6 series['Month'] = [d.year for d in series.Date]
#       7 series['Passengers'] = [d.strftime('%b') for d in series.Date]
#       8 years = series['year'].unique()
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Date'
